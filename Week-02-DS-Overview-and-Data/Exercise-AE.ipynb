# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.size
# Out:
# 7625

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
# df_food.columns
df_food.dtypes
df_food.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
new_df = df_food.filter(['calories_day', 'weight', 'gender'], axis=1)
new_df.head()
# Out:
#    calories_day                    weight
# 0           NaN                       187
# 1           3.0                       155
# 2           4.0  I'm not answering this.
# 3           3.0             Not sure, 240
# 4           2.0                       190

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
nans = new_df.isna().sum()
nans
# Out:
# calories_day    19
# weight           2
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
new_df = new_df.dropna()

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
new_df['weight'] = pd.to_numeric(new_df['weight'], errors='coerce')
new_df
# Out:
#      calories_day  weight
# 1             3.0   155.0
# 2             4.0     NaN
# 3             3.0     NaN
# 4             2.0   190.0
# 5             3.0   190.0
# ..            ...     ...
# 118           3.0   140.0
# 119           3.0   185.0
# 120           4.0   156.0
# 121           2.0   180.0
# 123           4.0   135.0
#
# [104 rows x 2 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
new_df= new_df.dropna()
new_df
# Out:
#      calories_day  weight
# 1             3.0   155.0
# 4             2.0   190.0
# 5             3.0   190.0
# 6             3.0   180.0
# 7             3.0   137.0
# ..            ...     ...
# 118           3.0   140.0
# 119           3.0   185.0
# 120           4.0   156.0
# 121           2.0   180.0
# 123           4.0   135.0
#
# [101 rows x 2 columns]

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).

salary_df = pd.read_csv('./data/ask_a_manager_survey.csv', sep='\t')

salary_df
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
salary_df.size
# Out:
# 505116

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
salary_df.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
currCols = ['Timestamp', 'How old are you?', 'What industry do you work in?', 'Job title', 'If your job title needs additional context, please clarify here:', "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)", 'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.', 'Please indicate the currency', 'If "Other," please indicate the currency here: ', 'If your income needs additional context, please provide it here:', 'What country do you work in?', "If you're in the U.S., what state do you work in?", 'What city do you work in?', 'How many years of professional work experience do you have overall?', 'How many years of professional work experience do you have in your field?', 'What is your highest level of education completed?', 'What is your gender?', 'What is your race? (Choose all that apply.)']
changedCols = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed'	'gender', 'race']
old_new_map = dict(zip(currCols, changedCols))
salary_df = salary_df.rename(columns=old_new_map)
salary_df
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
salary_df['industry'].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
tech_df = salary_df[salary_df['industry'] == 'Computing or Tech' ]
tech_df
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

tech_df['industry'].value_counts()
# Out:
# industry
# Computing or Tech    4699
# Name: count, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
tech_usd_df = tech_df[tech_df['currency'] == 'USD']
tech_usd_df
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
tech_usd_df['country'].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Pakistan                       1
# Puerto Rico                    1
# America                        1
# Uniyed states                  1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replacing the country names
tech_usd_df['country'] = tech_usd_df['country'].replace({
    "United States": "US",
    "USA": "US",
    "U.S.": "US",
    "United States of America": "US"
})
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\2516464307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_usd_df['country'] = tech_usd_df['country'].replace({

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
# After replacement
tech_usd_df['country'].value_counts()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
#                   ...
# Mexico               1
# United Stateds       1
# ISA                  1
# singapore            1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
tech_usd_df['country'] = tech_usd_df['country'].str.lower().str.strip()
# Replacing the country names
tech_usd_df['country'] = tech_usd_df['country'].replace({
    "united states": "us",
    "usa": "us",
    "u.s.": "us",
    "united states of america": "us"
})
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\469258911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_usd_df['country'] = tech_usd_df['country'].str.lower().str.strip()
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\469258911.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_usd_df['country'] = tech_usd_df['country'].replace({

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
tech_usd_df['country'].value_counts()
# Out:
# country
# us                         3698
# u.s.a.                        7
# canada                        5
# israel                        5
# u.s.a                         3
# unitedstates                  2
# poland                        2
# new zealand                   2
# united kingdom                2
# united state of america       2
# brazil                        2
# spain                         2
# singapore                     2
# u.s                           2
# india                         2
# denmark                       2
# australia                     2
# nigeria                       2
# unite states                  2
# france                        2
# unites states                 1
# thailand                      1
# united stares                 1
# china                         1
# jamaica                       1
# ghana                         1
# japan                         1
# romania                       1
# san francisco                 1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
# tech_usd_df['salary'] = tech_usd_df['salary'].str.replace(',','')
# salary_stats_by_state = salary_df.groupby('state')['salary_in_usd'].agg(['min', 'mean', 'max'])
# salary_stats_by_state

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
tech_usd_df['salary'] = pd.to_numeric(tech_usd_df['salary'], errors='coerce')
tech_usd_df.dropna(subset=['salary'], inplace=True)
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\1638328334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_usd_df['salary'] = pd.to_numeric(tech_usd_df['salary'], errors='coerce')
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\1638328334.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_usd_df.dropna(subset=['salary'], inplace=True)

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
salary_stats_by_state = tech_usd_df.groupby('state')['salary'].agg(['min', 'mean', 'max'])
salary_stats_by_state
# Out:
#                                      min           mean        max
# state
# Alabama                          35000.0  117400.000000   350000.0
# Arizona                          35000.0   97833.333333   145000.0
# Arkansas                             4.0   58001.000000    95000.0
# California                           0.0  153286.988827   520000.0
# California, Colorado            176000.0  176000.000000   176000.0
# California, Maryland             81500.0   81500.000000    81500.0
# California, Oregon              200000.0  200000.000000   200000.0
# Colorado                         49400.0  109291.891892   165000.0
# Connecticut                      68000.0  161610.000000   270000.0
# Delaware                        169000.0  169000.000000   169000.0
# District of Columbia             59000.0  142923.076923   200000.0
# District of Columbia, Virginia  109200.0  109200.000000   109200.0
# Florida                          28800.0  210711.000000  2600000.0
# ...

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
tech_usd_df['timestamp'] = pd.to_datetime(tech_usd_df['timestamp'], format = 'mixed', errors='coerce')

tech_dated = tech_usd_df[tech_usd_df['timestamp'].dt.year.isin([2021, 2022,2023])]
tech_dated
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\355196231.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_usd_df['timestamp'] = pd.to_datetime(tech_usd_df['timestamp'], format = 'mixed', errors='coerce')
#                 timestamp    age           industry  \
# 8999  2021-04-27 17:02:03  35-44  Computing or Tech
# 11900 2021-04-28 06:41:31  45-54  Computing or Tech
# 15238 2021-04-28 16:45:53  18-24  Computing or Tech
# 15885 2021-04-28 17:22:37  25-34  Computing or Tech
# 18140 2021-04-28 22:49:19  25-34  Computing or Tech
# ...                   ...    ...                ...
# 27960 2023-05-09 17:57:30  45-54  Computing or Tech
# 27961 2023-05-28 16:10:53  45-54  Computing or Tech
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
usd_df = salary_df[salary_df['currency'] == "USD"]
usd_df
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
#
#                                         title title_context  salary  \
# 0          Research and Instruction Librarian           NaN  55,000
# ...

# %%
usd_df['country'] = usd_df['country'].str.lower().str.strip()
usd_df['country'].value_counts()
usd_df
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\2957188447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd_df['country'] = usd_df['country'].str.lower().str.strip()
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# ...

# %%
usd_df['country'] =usd_df['country'].replace({'united states': 'US',
                'usa': 'US',
                'us' : 'US',
                'u.s.': 'US',
                'united states of america':"US",
                'u.s':'US'})
usd_df['country'].value_counts()
usd_df
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\3359026401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd_df['country'] =usd_df['country'].replace({'united states': 'US',
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# ...

# %%
usd_df = usd_df[usd_df['country'] == 'US']
usd_df['country'].value_counts()
usd_df
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28044   6/3/2024 16:15:43  18-24              Computing or Tech
# 28051   7/1/2024 20:05:58  25-34              Computing or Tech
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
#
#                                         title title_context  salary  \
# 0          Research and Instruction Librarian           NaN  55,000
# ...

# %%
usd_df['salary'] = usd_df['salary'].str.replace(',','').str.strip()
usd_df
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\3586200293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd_df['salary'] = usd_df['salary'].str.replace(',','').str.strip()
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28044   6/3/2024 16:15:43  18-24              Computing or Tech
# ...

# %%
usd_df['salary'] = pd.to_numeric(usd_df['salary'], errors='coerce')
usd_df['salary'].isna().sum()
usd_df.dtypes
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_18108\1456421178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd_df['salary'] = pd.to_numeric(usd_df['salary'], errors='coerce')
# timestamp                                       object
# age                                             object
# industry                                        object
# title                                           object
# title_context                                   object
# salary                                           int64
# additional_compensation                        float64
# currency                                        object
# other_currency                                  object
# ...

# %%
usd_df['state'].value_counts()
tripple_m_by_state = usd_df.groupby(by='state')['salary'].agg(['mean','min','max'])
tripple_m_by_state
# Out:
#                                         mean     min      max
# state
# Alabama                         71296.327586      54   350000
# Alabama, California             29120.000000   29120    29120
# Alabama, District of Columbia  156000.000000  156000   156000
# Alabama, Kansas                 64197.000000   64197    64197
# Alabama, Minnesota, Nevada     130000.000000  130000   130000
# ...                                      ...     ...      ...
# Virginia                        94753.340617      57  1300000
# Washington                     107158.670929      72  1260000
# West Virginia                   58664.170732       0   125000
# Wisconsin                       76582.185745       1   920000
# Wyoming                         58896.652174   29000   140000
#
# [129 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
styled_df = usd_df.style.format({'salary': "${:,.2f}"})

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
singles_only = usd_df[~usd_df['state'].str.contains(',', na =False)]
singles_only['state'].value_counts()
# Out:
# state
# California              2576
# New York                2160
# Massachusetts           1505
# Texas                   1249
# Illinois                1201
# Washington              1173
# District of Columbia     967
# Pennsylvania             937
# Virginia                 778
# Minnesota                711
# Ohio                     647
# Colorado                 627
# Oregon                   617
# North Carolina           597
# Maryland                 558
# Michigan                 538
# Georgia                  533
# Florida                  517
# Wisconsin                463
# New Jersey               392
# Missouri                 336
# Indiana                  327
# Arizona                  299
# Tennessee                279
# Connecticut              234
# Utah                     204
# Kentucky                 190
# Iowa                     178
# Kansas                   152
# South Carolina           144
# Louisiana                128
# Maine                    125
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
